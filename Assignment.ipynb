# %%
print ('*'*10)
print ('*'*10)
print ('*'*10)
print ('*'*10)
# Out:
# **********
# **********
# **********
# **********

# %%
print ('*'*10)
print ('*', ' '*6, '*')
print ('*', ' '*6, '*')
print ('*'*10)
# Out:
# **********
# *        *
# *        *
# **********

# %%
print( '*')
print('*'*2)
print('*'*3)
print('*'*4)
# Out:
# *
# **
# ***
# ****

# %%
x=(512-282)/((47*48)+5)
print('it is roughly' , x)
# Out:
# it is roughly 0.1017249004865104

# %%
num = eval(input('Enter a number'))
print ('The square of', num , 'is' , num * num, sep = ' ')
# Out:
# Enter a number 5
# The square of 5 is 25

# %%
x = eval(input('Enter a number:'))
print(x,'---',2*x,'---',3*x,'---',4*x,'---',5*x, sep = '')
# Out:
# Enter a number: 7
# 7---14---21---28---35

# %%
weight = eval(input('Enter a weight in kilogram:'))
print('Weight converted to pounds', weight*2.2)
# Out:
# Enter a weight in kilogram: 5
# Weight converted to pounds 11.0

# %%
x = eval(input())
y = eval(input())
z = eval(input())
total = x + y + z
average = total/3
print('total=',total,',average=',average)
# Out:
#  2
#  3
#  4
# total= 9 ,average= 3.0

# %%
meal = eval(input('Price of meal'))
y = eval(input('leave a tip %'))
tip = (y/100)*meal
print (tip)
print ('your total amount of bill:', meal + tip)
# Out:
# Price of meal 1000
# leave a tip % 3
# 30.0
# your total amount of bill: 1030.0
